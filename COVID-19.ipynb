# %% [markdown]
# # Analysis of Johns Hopkins CSSE data on COVID-19 Pandemic
#
# https://systems.jhu.edu/research/public-health/ncov/
#
# https://github.com/CSSEGISandData/COVID-19/

# %%
#!git clone https://github.com/CSSEGISandData/COVID-19/
#!cd COVID-19
#git pull

# %%
import pandas as pd
import matplotlib.pyplot as plt
#plt.style.use('dark_background')
import sys

if sys.platform=='darwin': 
    path1='/Volumes/GoogleDrive/My Drive/Research/github/'

elif sys.platform=='win32': 
    path1='G:/My Drive/Research/github/'

elif sys.platform=='linux2': 
    path1='~/'
else: 
    path1=''

#path2=path1+'covid-19-data/'
path2=path1+'COVID-19/csse_covid_19_data/csse_covid_19_time_series/'
#path2=path1+'archived_data/archived_time_series/'

files=[
    'time_series_covid19_confirmed_global.csv',
    'time_series_covid19_recovered_global.csv',
    'time_series_covid19_deaths_global.csv',
#'time_series_19-covid-Confirmed.csv',
#'time_series_19-covid-Deaths.csv',
#'time_series_19-covid-Recovered.csv'
]

df=[]
for file in files:
    df_index=pd.read_csv(path2+file)
    df.append(df_index)
    
fig=plt.figure();
fig, ax = plt.subplots();
#I=df[0][(df[0]['Province/State']=='Hubei')]
#D=df[1][(df[0]['Province/State']=='Hubei')]
#R=df[2][(df[0]['Province/State']=='Hubei')]
I=df[0]
R=df[1]
D=df[2]
I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
plt.legend(loc='upper left')
ax.twinx()
D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/R.sum()[-1]),color='#2ca02c')
plt.legend(loc='upper right')
plt.title('Covid19')

plt.show()

# %%
fig=plt.figure();
fig, ax = plt.subplots();
I=df[0][(df[0]['Country/Region']=='China')]
D=df[1][(df[0]['Country/Region']=='China')]
R=df[2][(df[0]['Country/Region']=='China')]
#I=df[0]
#D=df[1]
#R=df[2]
I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
plt.legend()
ax.twinx()
#D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/R.sum()[-1]),color='#2ca02c')
D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/(R.sum()[-1]+I.sum()[-1])),color='#2ca02c')
plt.legend(loc='upper right')
plt.title('Covid19 China')
# Out:
# /Users/mattferguson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Covid19 China')

# %%
fig=plt.figure();
fig, ax = plt.subplots();
I=df[0][(df[0]['Country/Region']=='US')]
D=df[1][(df[0]['Country/Region']=='US')]
R=df[2][(df[0]['Country/Region']=='US')]
#I=df[0]
#D=df[1]
#R=df[2]
I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
plt.legend(loc='upper left')
ax.twinx()
R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/(R.sum()[-1]+I.sum()[-1])),color='#2ca02c')
plt.legend(loc='upper right')
plt.title('Covid19 US')
# Out:
# /Users/mattferguson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Covid19 US')

# %%
fig=plt.figure();
fig, ax = plt.subplots();
I=df[0][(df[0]['Country/Region']=='Italy')]
D=df[1][(df[0]['Country/Region']=='Italy')]
R=df[2][(df[0]['Country/Region']=='Italy')]
#I=df[0]
#D=df[1]
#R=df[2]
I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
plt.legend(loc='upper left')
ax.twinx()
R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/(R.sum()[-1]+I.sum()[-1])),color='#2ca02c')
plt.legend(loc='upper right')
plt.title('Covid19 Italy')
# Out:
# /Users/mattferguson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Covid19 Italy')

# %%
fig=plt.figure();
fig, ax = plt.subplots();
I=df[0][(df[0]['Country/Region']=='Iran')]
D=df[1][(df[0]['Country/Region']=='Iran')]
R=df[2][(df[0]['Country/Region']=='Iran')]
#I=df[0]
#D=df[1]
#R=df[2]
I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
plt.legend(loc='upper left')
ax.twinx()
R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/(R.sum()[-1]+I.sum()[-1])),color='#2ca02c')
plt.legend(loc='upper right')
plt.title('Covid19 Iran')
# Out:
# /Users/mattferguson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Covid19 Iran')

# %%
fig=plt.figure();
fig, ax = plt.subplots();
I=df[0][(df[0]['Country/Region']=='France')]
D=df[1][(df[0]['Country/Region']=='France')]
R=df[2][(df[0]['Country/Region']=='France')]
#I=df[0]
#D=df[1]
#R=df[2]
I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
plt.legend(loc='upper left')
ax.twinx()
R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/(R.sum()[-1]+I.sum()[-1])),color='#2ca02c')
plt.legend(loc='upper right')
plt.title('Covid19 France')
# Out:
# /Users/mattferguson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Covid19 France')

# %%
fig=plt.figure();
fig, ax = plt.subplots();
I=df[0][(df[0]['Country/Region']=='United Kingdom')]
D=df[1][(df[0]['Country/Region']=='United Kingdom')]
R=df[2][(df[0]['Country/Region']=='United Kingdom')]
#I=df[0]
#D=df[1]
#R=df[2]
I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
plt.legend(loc='upper left')
ax.twinx()
R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/(R.sum()[-1]+I.sum()[-1])),color='#2ca02c')
plt.legend(loc='upper right')
plt.title('Covid19 United Kingdom')
# Out:
# /Users/mattferguson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Covid19 United Kingdom')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#path=path2+'csse_covid_19_data/csse_covid_19_time_series/'
path=path1+'COVID-19/csse_covid_19_data/csse_covid_19_time_series/'
files=[
#    'us-states.csv',
#    'us-counties.csv',
    'time_series_covid19_confirmed_global.csv',
    'time_series_covid19_recovered_global.csv',
    'time_series_covid19_deaths_global.csv',
#    'time_series_19-covid-Confirmed_archived_0325.csv',
#    'time_series_19-covid-Recovered_archived_0325.csv'
#    'time_series_19-covid-Deaths_archived_0325.csv',
]

df=[]
for file in files:
    df_index=pd.read_csv(path+file)
    df.append(df_index)
    
#df_pop=pd.read_csv('populations.csv', lineterminator='\n')
df_pop=pd.read_excel(path1+'COVID-19/populations.xlsx',header=None)

def covid19(nation):
    pop=df_pop[(df_pop[0]==nation)][1].values*1.e-5
    I=df[0][(df[0]['Country/Region']==nation)]
    D=df[1][(df[0]['Country/Region']==nation)]
    #R=df[2][(df[0]['Country/Region']==nation)]
    #I=df[0]
    #D=df[1]
    #R=df[2]
    #I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
    #I.sum().T[4:].plot(logy=True,label=nation+': {:,.0f}'.format(I.sum()[-1]))
    #print(I.columns[4:])
    I2=I.sum().T[4:]
    #I2=I.sum().T[4:].values
    I2=[I2/pop for I2 in I2]
    #print(np.array(I2).flatten().T[1:3])
    I2=np.array(I2).flatten().T
    #plt.semilogy(I.columns[4:],J,'.-',label=nation)
    plt.semilogy(I2,'.',label=nation)
    plt.xlim(0,1e2)
    plt.ylim(1e-3,1e2)
    #plt.ylim(1e-2,1e2)
    #plt.legend(loc='upper left')
    #plt.legend(bbox_to_anchor=(.05, 1), loc='upper left', borderaxespad=0.)
    plt.legend(bbox_to_anchor=(.95, 1), loc='upper left', borderaxespad=0.)
    ax.grid(which='minor',alpha=0.25)
    ax.grid(which='major',alpha=0.5)
    #ax2.twinx()
    #R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
    #D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/R.sum()[-1]),color='#2ca02c')
    #plt.legend(loc='upper right')
    #plt.title('Covid19 '+nation)
    
    from scipy.optimize import curve_fit
    def exp(x, a, b, c):#exponential
        return a * np.exp(x/b) + c
    x=np.arange(len(I2))
    #print(x,I2)
    start=45
    end=len(I2)
    #print(x[start:end].size,I2[start:end].size)
    popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,3.,0.], maxfev=10000)
    #popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,0.3,0.])
    perr = np.sqrt(np.diag(pcov))
    #print(popt,perr)
    plt.plot(x[start:end], exp(x[start:end], *popt), '-',label=' b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    #plt.plot(x[start:end], exp(x[start:end], *popt), '-',label=r'a: '+'{:,.2f}'.format(popt[0])+r'$\pm$'+'{:,.2f}'.format(perr[0])+' b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    plt.legend(bbox_to_anchor=(.95, 1), loc='upper left', borderaxespad=0.)


    
nations=[
    'China',
    'Korea, South',
    'Japan',
    'Italy',
    'Iran',
#    'Spain',
    'France',
    'United Kingdom',
    'US'
]
fig=plt.figure();
fig, ax = plt.subplots(figsize=(10,6));
for nation in nations:
    covid19(nation)

plt.show()
# Out:
# /Users/mattferguson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from labellines import labelLine, labelLines

#path=path2+'csse_covid_19_data/csse_covid_19_time_series/'
path=path1+'COVID-19/csse_covid_19_data/csse_covid_19_time_series/'
files=[
#    'us-states.csv',
#    'us-counties.csv',
    'time_series_covid19_confirmed_global.csv',
    'time_series_covid19_recovered_global.csv',
    'time_series_covid19_deaths_global.csv',
#    'time_series_19-covid-Confirmed_archived_0325.csv',
#    'time_series_19-covid-Recovered_archived_0325.csv'
#    'time_series_19-covid-Deaths_archived_0325.csv',
]

df=[]
for file in files:
    df_index=pd.read_csv(path+file)
    df.append(df_index)
    
#df_pop=pd.read_csv('populations.csv', lineterminator='\n')
df_pop=pd.read_excel(path1+'COVID-19/populations.xlsx',header=None)

def covid19(df,nation,title):
    pop=df_pop[(df_pop[0]==nation)][1].values*1.e-5
    I=df[(df['Country/Region']==nation)]
    #I=df[0][(df[0]['Country/Region']==nation)]
    #D=df[1][(df[0]['Country/Region']==nation)]
    #R=df[2][(df[0]['Country/Region']==nation)]
    #I=df[0]
    #D=df[1]
    #R=df[2]
    #I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
    #I.sum().T[4:].plot(logy=True,label=nation+': {:,.0f}'.format(I.sum()[-1]))
    #print(I.columns[4:])
    #print(I.sum().T[4:].index)
    I2=I.sum().T[4:]
    I2=[I2/pop for I2 in I2]
    I2=np.array(I2).flatten().T
    #I2=np.array(I2).T[0]
    x=np.arange(len(I2))
    #plt.semilogy(I.columns[4:],J,'.-',label=nation)
    plt.semilogy(x,I2,'.',basey=10,label=nation+': {:,.1f}'.format(I2[-1]))
    #plt.plot(I2,'.-',label=nation+': {:,.1f}'.format(I2[-1][0]))
    #labelLines(plt.gca().get_lines(), align=True, zorder=2.5)
    plt.xlim(0,1e2)
    plt.ylim(1e-3,1e3)
    #plt.ylim(1e-2,1e2)    #plt.legend(loc='upper left')
    #plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=2.5)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.title('COVID-19 Coronavirus '+title+' per 100,000'+' Worldwide by Country')
    plt.ylabel(title+' per 100,000')
    ax.grid(which='minor',alpha=0.25)
    ax.grid(which='major',alpha=0.5)
    #ax2.twinx()
    #R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
    #D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/R.sum()[-1]),color='#2ca02c')
    #plt.legend(loc='upper right')
    #plt.title('Covid19 '+nation)
    
    from scipy.optimize import curve_fit
    def exp(x, a, b, c):#exponential
        return a * np.exp(x/b) + c
    x=np.arange(len(I2))
    #print(x,I2)
    start=45
    end=len(I2)
    popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,3.,0.], maxfev=10000)
    #popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,0.3,0.])
    perr = np.sqrt(np.abs(np.diag(pcov)))
    #print(popt,perr)
    #plt.plot(x[start:end], exp(x[start:end], *popt), '-',label=r'a: '+'{:,.2f}'.format(popt[0])+r'$\pm$'+'{:,.2f}'.format(perr[0])+' b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))

    #plt.plot(x[start:end], exp(x[start:end], *popt), '-',label='b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    ex=np.arange(start,1e2)
    #print(popt,perr)
    plt.plot(ex, exp(ex, *popt), '-',label='b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    
    plt.savefig('COVID-19 Coronavirus '+title+' per 100,000'+' Worldwide by Country.png',bbox_inches='tight')
    plt.savefig('COVID-19 Coronavirus '+title+' per 100,000'+' Worldwide by Country.pdf',bbox_inches='tight')
    
nations=[
    'China',
#    'Korea, South',
    'Japan',
#    'Denmark',
#    'Norway',
#    'Switzerland',
#    'Austria',
#    'Greece',
    'Iran',
    'Italy',
#    'Spain',
#    'France',
#    'United Kingdom',
#    'US'
]
i=0
SIR=['Confirmed','Deaths','Recovering']
for df_i in df: 
    fig=plt.figure();
    fig, ax = plt.subplots(figsize=(10,6));
    plt.gca().set_prop_cycle(color=['r','r','g','g','b','b','c','c','m','m','y','y','k','k'])
    title=SIR[i]
    i+=1
    for nation in nations:
        print(nation)
        covid19(df_i,nation,title)

plt.show()
# Out:
# China
# Japan
# Iran
# Italy
# China
# Japan
# Iran
# Italy
# China
# Japan
# Iran
# Italy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from labellines import labelLine, labelLines

#plt.gca().set_prop_cycle(color=['r','r','g','g','b','b','c','c','m','m','y','y','k','k'])

#path=path2+'csse_covid_19_data/csse_covid_19_time_series/'
path=path1+'COVID-19/csse_covid_19_data/csse_covid_19_time_series/'
files=[
#    'us-states.csv',
#    'us-counties.csv',
    'time_series_covid19_confirmed_global.csv',
    'time_series_covid19_recovered_global.csv',
    'time_series_covid19_deaths_global.csv',
#    'time_series_19-covid-Confirmed_archived_0325.csv',
#    'time_series_19-covid-Recovered_archived_0325.csv'
#    'time_series_19-covid-Deaths_archived_0325.csv',
]

df=[]
for file in files:
    df_index=pd.read_csv(path+file)
    df.append(df_index)
    
#df_pop=pd.read_csv('populations.csv', lineterminator='\n')
df_pop=pd.read_excel(path1+'COVID-19/populations.xlsx',header=None)

def fit_it(I2):    
    from scipy.optimize import curve_fit
    def exp(x, a, b, c):#exponential
        return a * np.exp(x/b) + c
    #print(x,I2)
    #start=48
    #end=58
    start=0
    end=len(I2)-1
    #x=np.arange(len(I2))
    x=np.arange(48,58)
    popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,3.,0.], maxfev=10000)
    #popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,0.3,0.])
    perr = np.sqrt(np.abs(np.diag(pcov)))
    #plt.plot(x[start:end], exp(x[start:end], *popt), '-',label=r'a: '+'{:,.2f}'.format(popt[0])+r'$\pm$'+'{:,.2f}'.format(perr[0])+' b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    #plt.plot(x[start:end], exp(x[start:end], *popt), '-',label='b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    ex=np.arange(start,75)
    #print(popt,perr)
    plt.plot(ex, exp(ex, *popt), '-',label='b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

def covid19(df,nation,title):
    pop=df_pop[(df_pop[0]==nation)][1].values*1.e-5
    I=df[((df['Country/Region']==nation)|(df['Province/State']==nation))]
    #I=df[0][(df[0]['Country/Region']==nation)]
    #D=df[1][(df[0]['Country/Region']==nation)]
    #R=df[2][(df[0]['Country/Region']==nation)]
    #I=df[0]
    #D=df[1]
    #R=df[2]
    #I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
    #I.sum().T[4:].plot(logy=True,label=nation+': {:,.0f}'.format(I.sum()[-1]))
    #print(I.columns[4:])
    #print(I.sum().T[4:].index)
    
    #I2=I.sum().T[4:]
    #I2=[I2/pop for I2 in I2]
    #I2=np.array(I2).T[0]
    I2=np.array(I.T[4:]).T[0]
    #print(I2)
    
    #x=np.arange(len(I2))
    x=np.arange(47,58)
    I2=I2[47:58]
    #print(x,I2)
    #plt.semilogy(I.columns[4:],J,'.-',label=nation)
    plt.semilogy(x,I2,'.',basey=10,label=nation+': {:,.1f}'.format(I2[-1]))
    #plt.plot(x,I2,'.',label=nation+': {:,.1f}'.format(I2[-1]))
    #plt.plot(I2,'.-',label=nation+': {:,.1f}'.format(I2[-1][0]))
    #labelLines(plt.gca().get_lines(), align=True, zorder=2.5)
    plt.xlim(47,100)
    #plt.xlim(0,1e2)
    #plt.ylim(1e-3,1e3)
    plt.ylim(1e-0,3e5)
    #plt.legend(loc='upper left')
    #plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=2.5)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.title('COVID-19 Coronavirus '+title+' per 100,000'+' by State')
    plt.ylabel(title+' per 100,000')
    ax.grid(which='minor',alpha=0.25)
    ax.grid(which='major',alpha=0.5)
    #ax2.twinx()
    #R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
    #D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/R.sum()[-1]),color='#2ca02c')
    #plt.legend(loc='upper right')
    #plt.title('Covid19 '+nation)
    
    fit_it(I2)
    plt.savefig('COVID-19 Coronavirus '+title+' per 100,000'+' by State.png',bbox_inches='tight')
    plt.savefig('COVID-19 Coronavirus '+title+' per 100,000'+' by State.pdf',bbox_inches='tight')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    #plt.show()
    
nations=[
#    'China',
#    'South Korea',
#    'Japan',
#    'Italy',
#    'Iran',
#    'Spain',
#    'France',
#    'United Kingdom',
#    'US',
    'New York',
    'Washington',
    'California',
    'Florida',
    'Colorado',
    'Nevada',
    'Oregon',
    'Utah',
    'Idaho',
    'Montana',
    'Wyoming',
    'New Mexico'
]
'''
'District of Columbia',
'New Jersey',
'Puerto Rico',
'Rhode Island',
'Massachusetts',
'Guam',
#'US Virgin Islands',
'Connecticut',
#'American Samoa',
'Maryland',
'Delaware',
'New York',
'Florida',
#'Northern Mariana Islands',
'Pennsylvania',
'Ohio',
'California',
'Illinois',
'Hawaii',
'Virginia',
'North Carolina',
'Indiana',
'Georgia',
'Michigan',
'South Carolina',
'Tennessee',
'New Hampshire',
'Kentucky',
'Louisiana',
'Washington',
'Wisconsin',
'Texas',
'Alabama',
'Missouri',
'West Virginia',
'Minnesota',
'Vermont',
'Mississippi',
'Arizona',
'Arkansas',
'Oklahoma',
'Iowa',
'Colorado',
'Maine',
'Oregon',
'Utah',
'Kansas',
'Nevada',
'Nebraska',
'Idaho',
'New Mexico',
'South Dakota',
'North Dakota',
'Montana',
'Wyoming',
'Alaska',
]
'''
    
i=0
SIR=['Confirmed','Deaths','Recovering']
for df_i in df: 
    fig=plt.figure();
    fig, ax = plt.subplots(figsize=(10,6));
    plt.gca().set_prop_cycle(color=['r','r','g','g','b','b','c','c','m','m','y','y','k','k'])
    title=SIR[i]
    i+=1
    for nation in nations:
    #for state in states:
        print(nation)
        covid19(df_i,nation,title)

plt.show()
# Out:
# New York
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-afcebfb65919> in <module>
#     194     #for state in states:
#     195         print(nation)
# --> 196         covid19(df_i,nation,title)
#     197
#     198 plt.show()
#
# <ipython-input-17-afcebfb65919> in covid19(df, nation, title)
#      65     #I2=[I2/pop for I2 in I2]
#      66     #I2=np.array(I2).T[0]
# ---> 67     I2=np.array(I.T[4:]).T[0]
#      68     #print(I2)
#      69
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from labellines import labelLine, labelLines

#plt.gca().set_prop_cycle(color=['r','r','g','g','b','b','c','c','m','m','y','y','k','k'])


path='archived_data/archived_time_series/'
#path='csse_covid_19_data/csse_covid_19_time_series/'
#path='COVID-19/csse_covid_19_data/csse_covid_19_time_series/'
files=[
'time_series_19-covid-Confirmed_archived_0325.csv',
'time_series_19-covid-Deaths_archived_0325.csv',
'time_series_19-covid-Recovered_archived_0325.csv'
]

df=[]
for file in files:
    df_index=pd.read_csv(path+file)
    df.append(df_index)
    
#df_pop=pd.read_csv('populations.csv', lineterminator='\n')
df_pop=pd.read_excel('populations.xlsx',header=None)

def fit_it(I2):    
    from scipy.optimize import curve_fit
    def exp(x, a, b, c):#exponential
        return a * np.exp(b*x) + c
    #print(x,I2)
    start=0
    end=100
    #start=0
    #end=len(I2)-1
    x=np.arange(len(I2))
    #x=np.arange(48,58)
    popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,0.3,0.], maxfev=10000)
    #popt, pcov = curve_fit(exp, x[start:end], I2[start:end], p0=[1.,0.3,0.])
    perr = np.sqrt(np.abs(np.diag(pcov)))
    #plt.plot(x[start:end], exp(x[start:end], *popt), '-',label=r'a: '+'{:,.2f}'.format(popt[0])+r'$\pm$'+'{:,.2f}'.format(perr[0])+' b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    #plt.plot(x[start:end], exp(x[start:end], *popt), '-',label='b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    ex=np.arange(start,end)
    #print(popt,perr)
    plt.plot(ex, exp(ex, *popt), '-',label='b: %3.2f$\pm$%3.2f'% tuple([popt[1],perr[1]]))
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    


def covid19(df,nation,title):
    pop=df_pop[(df_pop[0]==nation)][1].values*1.e-5
    I=df[((df['Country/Region']==nation)|(df['Province/State']==nation))]
    #I=df[0][(df[0]['Country/Region']==nation)]
    #D=df[1][(df[0]['Country/Region']==nation)]
    #R=df[2][(df[0]['Country/Region']==nation)]
    #I=df[0]
    #D=df[1]
    #R=df[2]
    #I.sum().T[4:].plot(label='Infected: {:,.0f}'.format(I.sum()[-1]),color='#1f77b4')
    #I.sum().T[4:].plot(logy=True,label=nation+': {:,.0f}'.format(I.sum()[-1]))
    #print(I.columns[4:])
    #print(I.sum().T[4:].index)

    #Countries
    #I2=I.sum().T[4:]
    #I2=[I2/pop for I2 in I2]
    #I2=np.array(I2).T[0]
    #States
    I2=np.array(I.T[4:]).T[0]
    #print(I2)
    
    x=np.arange(len(I2))
    #x=np.arange(47,58)
    #I2=I2[47:58]
    #print(x,I2)
    #plt.semilogy(I.columns[4:],J,'.-',label=nation)
    plt.semilogy(x,I2,'.',basey=10,label=nation+': {:,.1f}'.format(I2[-1]))
    #plt.plot(x,I2,'.',label=nation+': {:,.1f}'.format(I2[-1]))
    #plt.plot(I2,'.-',label=nation+': {:,.1f}'.format(I2[-1][0]))
    #labelLines(plt.gca().get_lines(), align=True, zorder=2.5)
    #plt.xlim(0,100)
    #plt.xlim(0,1e2)
    #plt.ylim(1e-3,1e5)
    #plt.ylim(1e-0,3e5)
    #plt.legend(loc='upper left')
    #plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=2.5)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.title('COVID-19 Coronavirus '+title+' per 100,000'+' by State')
    plt.ylabel(title+' per 100,000')
    ax.grid(which='minor',alpha=0.25)
    ax.grid(which='major',alpha=0.5)
    #ax2.twinx()
    #R.sum().T[4:].plot(label='Recovering: {:,.0f}'.format(R.sum()[-1]),color='#ff7f0e')
    #D.sum().T[4:].plot(label='Dead: {:,.0f}, {:,.3f}'.format(D.sum()[-1],D.sum()[-1]/R.sum()[-1]),color='#2ca02c')
    #plt.legend(loc='upper right')
    #plt.title('Covid19 '+nation)
    
    fit_it(I2)
    plt.savefig('COVID-19 Coronavirus '+title+' per 100,000'+' by State.png',bbox_inches='tight')
    plt.savefig('COVID-19 Coronavirus '+title+' per 100,000'+' by State.pdf',bbox_inches='tight')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    #plt.show()
    
nations=[
#    'China',
#    'Korea, South',
#    'Japan',
#    'Italy',
#    'Iran',
#    'Spain',
#    'France',
#    'United Kingdom',
#    'US',
    'New York',
    'Washington',
    'California',
    'Florida',
    'Colorado',
    'Nevada',
    'Oregon',
    'Utah',
    'Idaho',
    'Montana',
    'Wyoming',
    'New Mexico',
    'Texas',
]
    
i=0
SIR=['Confirmed','Deaths','Recovering']
for df_i in df: 
    fig=plt.figure();
    fig, ax = plt.subplots(figsize=(10,6));
    plt.gca().set_prop_cycle(color=['r','r','g','g','b','b','c','c','m','m','y','y','k','k'])
    title=SIR[i]
    i+=1
    for nation in nations:
    #for state in states:
        #print(nation)
        covid19(df_i,nation,title)

plt.show()

# %% [markdown]
# ### ![](covid19_update1.png)

# %% [markdown]
# ## Covid19 Snapshot showing cumulative deaths by day in Italy and Spain
# from: https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv
#
# ![](Italy-Spain.png)

# %% [markdown]
# ![](hospital_bed_capacity_and_covid_estimates.png)

# %% [markdown]
# ![](ICU_beds.jpeg)

# %%
import pandas as pd

df=pd.read_excel('deaths per 100000 by cause.xlsx')
#df[(df['Table 5. Age-adjusted death rates for selected causes of death, by sex, race, and Hispanic origin: United States, selected years 1950–2017	']=='Influenza and pneumonia7/')]
d={'Cause':['Influenza','All causes'],'US deaths per 100000 per year':[14.3,731.9],'US deaths per 100000 per month':['{:.1f}'.format(14.3/12),'{:.1f}'.format(731.9/12)],'\"Lombardy\" deaths per 100000 per month':['{:.1f}'.format(14.3/12/6),'{:.1f}'.format(731.9/12/6)]}
df = pd.DataFrame(data=d)
df

# %% [markdown]
# I might try this out later. https://github.com/os/slacker

# %%
from slacker import Slacker

slack = Slacker('<your-slack-api-token-goes-here>')

# Send a message to #general channel
slack.chat.post_message('#general', 'Hello fellow slackers!')

# Get users list
response = slack.users.list()
users = response.body['members']

# Upload a file
slack.files.upload('hello.txt')

# If you need to proxy the requests
proxy_endpoint = 'http://myproxy:3128'
slack = Slacker('<your-slack-api-token-goes-here>',
                http_proxy=proxy_endpoint,
                https_proxy=proxy_endpoint)

# Advanced: Use `request.Session` for connection pooling (reuse)
from requests.sessions import Session
with Session() as session:
    slack = Slacker(token, session=session)
    slack.chat.post_message('#general', 'All these requests')
    slack.chat.post_message('#general', 'go through')
    slack.chat.post_message('#general', 'a single https connection')
